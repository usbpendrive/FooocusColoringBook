# %% [markdown]
# <a href="https://colab.research.google.com/github/usbpendrive/FooocusColoringBook/blob/main/fooocus_colab_coloring_book.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Prepare

# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/mashb1t/Fooocus.git
# %cd /content/Fooocus
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 72.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.16.0
#     Uninstalling pygit2-1.16.0:
#       Successfully uninstalled pygit2-1.16.0
# ...
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 11118, done.
# remote: Total 11118 (delta 0), reused 0 (delta 0), pack-reused 11118 (from 1)
# Receiving objects: 100% (11118/11118), 57.40 MiB | 12.87 MiB/s, done.
# Resolving deltas: 100% (6400/6400), done.
# /content/Fooocus

# %% [markdown]
# Run

# %%
# !aria2c -o models/loras/ColoringBookRedmond-ColoringBook-ColoringBookAF.safetensors https://civitai.com/api/download/models/136348?type=Model&format=SafeTensor
# Out:
# 11/19 07:15:58 [NOTICE] Downloading 1 item(s)
#
# 11/19 07:15:58 [NOTICE] CUID#7 - Redirecting to https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/2211721/model/murderDronesv1r.GOE0.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22Murder-DronesV1R.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20241119/us-east-1/s3/aws4_request&X-Amz-Date=20241119T071558Z&X-Amz-SignedHeaders=host&X-Amz-Signature=574b427da7dc9ff3adc7290b28b8b84cd654adc54e54de803b374ddaf1e18a71
#
# 11/19 07:16:01 [NOTICE] Download complete: /content/Fooocus/models/loras/ColoringBookRedmond-ColoringBook-ColoringBookAF.safetensors
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 494907|OK  |    19MiB/s|/content/Fooocus/models/loras/ColoringBookRedmond-ColoringBook-ColoringBookAF.safetensors
#
# ...

# %%
# !python entry_with_update.py --share --always-high-vram --attention-split
# Out:
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram', '--attention-split']
# Python 3.10.12 (main, Sep 11 2024, 15:47:36) [GCC 11.4.0]
# Fooocus version: 2.6.5 (mashb1t)
# Error checking version for torchsde: No package metadata was found for torchsde
# Installing requirements
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/xlvaeapp.pth" to /content/Fooocus/models/vae_approx/xlvaeapp.pth
#
# 100% 209k/209k [00:00<00:00, 57.7MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/vaeapp_sd15.pt" to /content/Fooocus/models/vae_approx/vaeapp_sd15.pth
#
# 100% 209k/209k [00:00<00:00, 30.9MB/s]
# Downloading: "https://huggingface.co/mashb1t/misc/resolve/main/xl-to-v1_interposer-v4.0.safetensors" to /content/Fooocus/models/vae_approx/xl-to-v1_interposer-v4.0.safetensors
#
# ...
